# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://platform.newzoo.com/general-rankings'
res = requests.get(url)

# %%
print(res.raise_for_status())
soup = BeautifulSoup(res.text)
type(soup)
# Out:
# None
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,shrink-to-fit=no" name="viewport"/>
#   <meta content="#000000" name="theme-color"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <link href="//cloud.typography.com/7361494/7456752/css/fonts.css" rel="stylesheet"/>
#   <script async="" defer="defer" id="hs-script-loader" src="//js.hs-scripts.com/700740.js" type="text/javascript">
#   </script>
#   <title>
#    Newzoo Analytics Platform
#   </title>
#   <link href="/static/css/2.b2d8bcc9.chunk.css" rel="stylesheet"/>
#   <link href="/static/css/main.c252558d.chunk.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <noscript>
#    You need to enable JavaScript to run this app.
#   </noscript>
#   <div id="root">
#   </div>
#   <script>
# ...

# %%
from selenium import webdriver
import sys
from selenium.webdriver.chrome.options import Options

# %%
options = Options()
# options.add_argument('--ignore-certificate-errors')
# options.add_argument('--incognito')
# options.add_argument('--headless')
options.add_argument('--window-size=500,300')

# %%
chrome_path = '/Users/carsonlloyd/Downloads/chromedriver'

# %%
driver = webdriver.Chrome(chrome_path, options=options)

# %%
driver.set_window_size(1400,1000)

# %%
driver.get(url)

# %%
element = driver.find_element_by_class_name('table-component ')

# %%
import pandas as pd
page_source = driver.page_source
soup = BeautifulSoup(page_source)
tables = soup.findAll('table')
table = tables[0].prettify()
df = pd.read_html(table)[0]

# %%
df = df.drop(['Unnamed: 0', 'Unnamed: 1'], axis = 1)

# %%
df
# Out:
#                    name        Q1        Q2        Q3        Q4     Total
# 0               Tencent  $5.21  B  $4.44  B  $4.65  B  $4.40  B  $18.7  B
# 1                  Sony  $3.08  B  $3.12  B  $3.61  B  $4.41  B  $14.2  B
# 2             Microsoft  $2.02  B  $2.03  B  $2.31  B  $3.39  B  $9.75  B
# 3                 Apple  $2.09  B  $2.30  B  $2.52  B  $2.54  B  $9.45  B
# 4   Activision Blizzard  $1.87  B  $1.54  B  $1.35  B  $2.13  B  $6.89  B
# 5                Google  $1.38  B  $1.46  B  $1.52  B  $2.13  B  $6.50  B
# 6               NetEase  $1.28  B  $1.47  B  $1.51  B  $1.61  B  $5.85  B
# 7                    EA  $1.58  B  $1.14  B  $1.29  B  $1.29  B  $5.29  B
# 8              Nintendo   $718  M   $751  M   $772  M  $2.14  B  $4.38  B
# 9          Bandai Namco   $807  M   $567  M   $693  M   $674  M  $2.74  B
# 10  TakeTwo Interactive   $450  M   $388  M   $493  M  $1.25  B  $2.58  B
# 11                Nexon   $803  M   $424  M   $615  M   $409  M  $2.25  B
# ...

# %%
driver.quit()
