# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options 
from bs4 import BeautifulSoup

# %%
options = Options() 
chrome_path = '/Users/carsonlloyd/Downloads/chromedriver'

# %%
options.add_argument('--window-size=500,300')

# %%
driver = webdriver.Chrome(chrome_path, 
                              options=options)

driver.set_window_size(1400,1000)

# %%
driver.get('https://finance.yahoo.com/quote/ATRX/history?period1=755222400&period2=1578787200&interval=1d&filter=history&frequency=1d')

# %%
import pandas as pd
page_source = driver.page_source
soup = BeautifulSoup(page_source)
tables = soup.findAll('table')
table = tables[0].prettify()
df = pd.read_html(table)[0]

# %%
df
# Out:
#                                                    Date  \
# 0                                          Jan 10, 2020
# 1                                          Jan 09, 2020
# 2                                          Jan 08, 2020
# 3                                          Jan 07, 2020
# 4                                          Jan 06, 2020
# ...                                                 ...
# 2896                                       Jul 15, 2008
# 2897                                       Jul 14, 2008
# 2898                                       Jul 11, 2008
# 2899                                       Jul 10, 2008
# 2900  *Close price adjusted for splits.  **Adjusted ...
#
#                                                    Open  \
# 0                                                0.0500
# 1                                                0.0500
# 2                                                0.0600
# 3                                                0.0500
# ...

# %%
driver.quit()
